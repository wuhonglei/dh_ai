# %%
import math
import matplotlib.pyplot as plt
import numpy as np


def cost(x): return x ** 2 * math.sin(x)
def gradient(x): return 2 * x * math.sin(x) + x ** 2 * math.cos(x)


x = np.linspace(1, 20, 200)
y = [gradient(i) for i in x]

iter = 10000
lr = 0.001
temp_x = 0.1

for i in range(iter):
    temp_x = temp_x - lr * gradient(temp_x)
    temp_y = gradient(temp_x)
    if i % 50 == 0:
        print(f'cost is {cost(temp_x)}', end='\r')
# Out:
# cost is 1.581673268904833e-055

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

random.seed(0)
def y(x): return 1.477 * x + 0.089
def f(x): return 1.477 * x + 0.089


# 生成 100 个服从高斯噪声 (0,1) 分布的数据


x = np.linspace(1, 15, 20)
plt.xlim(0, 20)
plt.scatter(x, y(x) + np.random.randn(len(x)), color='r', marker='+')
plt.plot(x, f(x), color='b')

# %%
np.random.rand(20)
# Out:
# array([0.01706049, 0.96705492, 0.61505802, 0.55243906, 0.29594983,
#        0.92929167, 0.26590563, 0.82814661, 0.98510868, 0.78339665,
#        0.51898992, 0.06607426, 0.47241379, 0.43825595, 0.20279604,
#        0.42358764, 0.35775788, 0.16368426, 0.44137414, 0.26279996])
