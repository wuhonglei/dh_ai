# %%
import numpy as np
import matplotlib.pyplot as plt


def step_function(x):
    # 定义阶跃函数
    return np.where(x >= 0, 1, 0)


# 生成数据
x = np.linspace(-10, 10, 1000)
y = step_function(x)

# 绘制阶跃函数
plt.plot(x, y)
plt.title("Step Function")
plt.xlabel("x")
plt.ylabel("H(x)")
plt.show()

# %%
np.where(np.array([-1, 0, 1]) >= 0, 1, 0)
# Out:
# array([0, 1, 1])

# %%
np.sign(1), np.sign(0), np.sign(-2)
# Out:
# (1, 0, -1)

# %%
import numpy as np
list_ = [1, 2, 3, 2,-1, 1]
np.argmax(list_), np.argmin(list_)
# Out:
# (2, 4)
