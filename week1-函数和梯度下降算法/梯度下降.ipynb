# %%
def gradient(x):
  return 2 * x - 4

def gradient_descent(x, learning_rate, steps):
  for i in range(steps):
    current_gradient = gradient(x)
    x = x - learning_rate * current_gradient
    print(f"step {i+1}: x = {x}, gradient = {current_gradient}")
  return x

# %%
gradient_descent(2.1, 0.001, 1000)
# Out:
# step 1: x = 2.0, gradient = 0
# step 2: x = 2.0, gradient = 0.0
# step 3: x = 2.0, gradient = 0.0
# step 4: x = 2.0, gradient = 0.0
# step 5: x = 2.0, gradient = 0.0
# step 6: x = 2.0, gradient = 0.0
# step 7: x = 2.0, gradient = 0.0
# step 8: x = 2.0, gradient = 0.0
# step 9: x = 2.0, gradient = 0.0
# step 10: x = 2.0, gradient = 0.0
# step 11: x = 2.0, gradient = 0.0
# step 12: x = 2.0, gradient = 0.0
# step 13: x = 2.0, gradient = 0.0
# step 14: x = 2.0, gradient = 0.0
# step 15: x = 2.0, gradient = 0.0
# step 16: x = 2.0, gradient = 0.0
# step 17: x = 2.0, gradient = 0.0
# step 18: x = 2.0, gradient = 0.0
# step 19: x = 2.0, gradient = 0.0
# step 20: x = 2.0, gradient = 0.0
# step 21: x = 2.0, gradient = 0.0
# step 22: x = 2.0, gradient = 0.0
# step 23: x = 2.0, gradient = 0.0
# step 24: x = 2.0, gradient = 0.0
# step 25: x = 2.0, gradient = 0.0
# step 26: x = 2.0, gradient = 0.0
# step 27: x = 2.0, gradient = 0.0
# step 28: x = 2.0, gradient = 0.0
# step 29: x = 2.0, gradient = 0.0
# step 30: x = 2.0, gradient = 0.0
# step 31: x = 2.0, gradient = 0.0
# step 32: x = 2.0, gradient = 0.0
# step 33: x = 2.0, gradient = 0.0
# step 34: x = 2.0, gradient = 0.0
# step 35: x = 2.0, gradient = 0.0
# step 36: x = 2.0, gradient = 0.0
# step 37: x = 2.0, gradient = 0.0
# step 38: x = 2.0, gradient = 0.0
# step 39: x = 2.0, gradient = 0.0
# step 40: x = 2.0, gradient = 0.0
# step 41: x = 2.0, gradient = 0.0
# step 42: x = 2.0, gradient = 0.0
# step 43: x = 2.0, gradient = 0.0
# step 44: x = 2.0, gradient = 0.0
# step 45: x = 2.0, gradient = 0.0
# step 46: x = 2.0, gradient = 0.0
# step 47: x = 2.0, gradient = 0.0
# step 48: x = 2.0, gradient = 0.0
# step 49: x = 2.0, gradient = 0.0
# step 50: x = 2.0, gradient = 0.0
# step 51: x = 2.0, gradient = 0.0
# step 52: x = 2.0, gradient = 0.0
# step 53: x = 2.0, gradient = 0.0
# step 54: x = 2.0, gradient = 0.0
# step 55: x = 2.0, gradient = 0.0
# step 56: x = 2.0, gradient = 0.0
# step 57: x = 2.0, gradient = 0.0
# step 58: x = 2.0, gradient = 0.0
# step 59: x = 2.0, gradient = 0.0
# step 60: x = 2.0, gradient = 0.0
# step 61: x = 2.0, gradient = 0.0
# step 62: x = 2.0, gradient = 0.0
# step 63: x = 2.0, gradient = 0.0
# step 64: x = 2.0, gradient = 0.0
# step 65: x = 2.0, gradient = 0.0
# step 66: x = 2.0, gradient = 0.0
# step 67: x = 2.0, gradient = 0.0
# step 68: x = 2.0, gradient = 0.0
# step 69: x = 2.0, gradient = 0.0
# step 70: x = 2.0, gradient = 0.0
# step 71: x = 2.0, gradient = 0.0
# step 72: x = 2.0, gradient = 0.0
# step 73: x = 2.0, gradient = 0.0
# step 74: x = 2.0, gradient = 0.0
# step 75: x = 2.0, gradient = 0.0
# step 76: x = 2.0, gradient = 0.0
# step 77: x = 2.0, gradient = 0.0
# step 78: x = 2.0, gradient = 0.0
# step 79: x = 2.0, gradient = 0.0
# step 80: x = 2.0, gradient = 0.0
# step 81: x = 2.0, gradient = 0.0
# step 82: x = 2.0, gradient = 0.0
# step 83: x = 2.0, gradient = 0.0
# step 84: x = 2.0, gradient = 0.0
# step 85: x = 2.0, gradient = 0.0
# step 86: x = 2.0, gradient = 0.0
# step 87: x = 2.0, gradient = 0.0
# step 88: x = 2.0, gradient = 0.0
# step 89: x = 2.0, gradient = 0.0
# step 90: x = 2.0, gradient = 0.0
# step 91: x = 2.0, gradient = 0.0
# step 92: x = 2.0, gradient = 0.0
# step 93: x = 2.0, gradient = 0.0
# step 94: x = 2.0, gradient = 0.0
# step 95: x = 2.0, gradient = 0.0
# step 96: x = 2.0, gradient = 0.0
# step 97: x = 2.0, gradient = 0.0
# step 98: x = 2.0, gradient = 0.0
# step 99: x = 2.0, gradient = 0.0
# step 100: x = 2.0, gradient = 0.0
# step 101: x = 2.0, gradient = 0.0
# step 102: x = 2.0, gradient = 0.0
# step 103: x = 2.0, gradient = 0.0
# step 104: x = 2.0, gradient = 0.0
# step 105: x = 2.0, gradient = 0.0
# step 106: x = 2.0, gradient = 0.0
# step 107: x = 2.0, gradient = 0.0
# step 108: x = 2.0, gradient = 0.0
# step 109: x = 2.0, gradient = 0.0
# step 110: x = 2.0, gradient = 0.0
# step 111: x = 2.0, gradient = 0.0
# step 112: x = 2.0, gradient = 0.0
# step 113: x = 2.0, gradient = 0.0
# step 114: x = 2.0, gradient = 0.0
# step 115: x = 2.0, gradient = 0.0
# step 116: x = 2.0, gradient = 0.0
# step 117: x = 2.0, gradient = 0.0
# step 118: x = 2.0, gradient = 0.0
# step 119: x = 2.0, gradient = 0.0
# step 120: x = 2.0, gradient = 0.0
# step 121: x = 2.0, gradient = 0.0
# step 122: x = 2.0, gradient = 0.0
# step 123: x = 2.0, gradient = 0.0
# step 124: x = 2.0, gradient = 0.0
# step 125: x = 2.0, gradient = 0.0
# step 126: x = 2.0, gradient = 0.0
# step 127: x = 2.0, gradient = 0.0
# step 128: x = 2.0, gradient = 0.0
# step 129: x = 2.0, gradient = 0.0
# step 130: x = 2.0, gradient = 0.0
# step 131: x = 2.0, gradient = 0.0
# step 132: x = 2.0, gradient = 0.0
# step 133: x = 2.0, gradient = 0.0
# step 134: x = 2.0, gradient = 0.0
# step 135: x = 2.0, gradient = 0.0
# step 136: x = 2.0, gradient = 0.0
# step 137: x = 2.0, gradient = 0.0
# step 138: x = 2.0, gradient = 0.0
# step 139: x = 2.0, gradient = 0.0
# step 140: x = 2.0, gradient = 0.0
# step 141: x = 2.0, gradient = 0.0
# step 142: x = 2.0, gradient = 0.0
# step 143: x = 2.0, gradient = 0.0
# step 144: x = 2.0, gradient = 0.0
# step 145: x = 2.0, gradient = 0.0
# step 146: x = 2.0, gradient = 0.0
# step 147: x = 2.0, gradient = 0.0
# step 148: x = 2.0, gradient = 0.0
# step 149: x = 2.0, gradient = 0.0
# step 150: x = 2.0, gradient = 0.0
# step 151: x = 2.0, gradient = 0.0
# step 152: x = 2.0, gradient = 0.0
# step 153: x = 2.0, gradient = 0.0
# step 154: x = 2.0, gradient = 0.0
# step 155: x = 2.0, gradient = 0.0
# step 156: x = 2.0, gradient = 0.0
# step 157: x = 2.0, gradient = 0.0
# step 158: x = 2.0, gradient = 0.0
# step 159: x = 2.0, gradient = 0.0
# step 160: x = 2.0, gradient = 0.0
# step 161: x = 2.0, gradient = 0.0
# step 162: x = 2.0, gradient = 0.0
# step 163: x = 2.0, gradient = 0.0
# step 164: x = 2.0, gradient = 0.0
# step 165: x = 2.0, gradient = 0.0
# step 166: x = 2.0, gradient = 0.0
# step 167: x = 2.0, gradient = 0.0
# step 168: x = 2.0, gradient = 0.0
# step 169: x = 2.0, gradient = 0.0
# step 170: x = 2.0, gradient = 0.0
# step 171: x = 2.0, gradient = 0.0
# step 172: x = 2.0, gradient = 0.0
# step 173: x = 2.0, gradient = 0.0
# step 174: x = 2.0, gradient = 0.0
# step 175: x = 2.0, gradient = 0.0
# step 176: x = 2.0, gradient = 0.0
# step 177: x = 2.0, gradient = 0.0
# step 178: x = 2.0, gradient = 0.0
# step 179: x = 2.0, gradient = 0.0
# step 180: x = 2.0, gradient = 0.0
# step 181: x = 2.0, gradient = 0.0
# step 182: x = 2.0, gradient = 0.0
# step 183: x = 2.0, gradient = 0.0
# step 184: x = 2.0, gradient = 0.0
# step 185: x = 2.0, gradient = 0.0
# step 186: x = 2.0, gradient = 0.0
# step 187: x = 2.0, gradient = 0.0
# step 188: x = 2.0, gradient = 0.0
# step 189: x = 2.0, gradient = 0.0
# step 190: x = 2.0, gradient = 0.0
# step 191: x = 2.0, gradient = 0.0
# step 192: x = 2.0, gradient = 0.0
# step 193: x = 2.0, gradient = 0.0
# step 194: x = 2.0, gradient = 0.0
# step 195: x = 2.0, gradient = 0.0
# step 196: x = 2.0, gradient = 0.0
# step 197: x = 2.0, gradient = 0.0
# step 198: x = 2.0, gradient = 0.0
# step 199: x = 2.0, gradient = 0.0
# step 200: x = 2.0, gradient = 0.0
# step 201: x = 2.0, gradient = 0.0
# step 202: x = 2.0, gradient = 0.0
# step 203: x = 2.0, gradient = 0.0
# step 204: x = 2.0, gradient = 0.0
# step 205: x = 2.0, gradient = 0.0
# step 206: x = 2.0, gradient = 0.0
# step 207: x = 2.0, gradient = 0.0
# step 208: x = 2.0, gradient = 0.0
# step 209: x = 2.0, gradient = 0.0
# step 210: x = 2.0, gradient = 0.0
# step 211: x = 2.0, gradient = 0.0
# step 212: x = 2.0, gradient = 0.0
# step 213: x = 2.0, gradient = 0.0
# step 214: x = 2.0, gradient = 0.0
# step 215: x = 2.0, gradient = 0.0
# step 216: x = 2.0, gradient = 0.0
# step 217: x = 2.0, gradient = 0.0
# step 218: x = 2.0, gradient = 0.0
# step 219: x = 2.0, gradient = 0.0
# step 220: x = 2.0, gradient = 0.0
# step 221: x = 2.0, gradient = 0.0
# step 222: x = 2.0, gradient = 0.0
# step 223: x = 2.0, gradient = 0.0
# step 224: x = 2.0, gradient = 0.0
# step 225: x = 2.0, gradient = 0.0
# step 226: x = 2.0, gradient = 0.0
# step 227: x = 2.0, gradient = 0.0
# step 228: x = 2.0, gradient = 0.0
# step 229: x = 2.0, gradient = 0.0
# step 230: x = 2.0, gradient = 0.0
# step 231: x = 2.0, gradient = 0.0
# step 232: x = 2.0, gradient = 0.0
# step 233: x = 2.0, gradient = 0.0
# step 234: x = 2.0, gradient = 0.0
# step 235: x = 2.0, gradient = 0.0
# step 236: x = 2.0, gradient = 0.0
# step 237: x = 2.0, gradient = 0.0
# step 238: x = 2.0, gradient = 0.0
# step 239: x = 2.0, gradient = 0.0
# step 240: x = 2.0, gradient = 0.0
# step 241: x = 2.0, gradient = 0.0
# step 242: x = 2.0, gradient = 0.0
# step 243: x = 2.0, gradient = 0.0
# step 244: x = 2.0, gradient = 0.0
# step 245: x = 2.0, gradient = 0.0
# step 246: x = 2.0, gradient = 0.0
# step 247: x = 2.0, gradient = 0.0
# step 248: x = 2.0, gradient = 0.0
# step 249: x = 2.0, gradient = 0.0
# step 250: x = 2.0, gradient = 0.0
# step 251: x = 2.0, gradient = 0.0
# step 252: x = 2.0, gradient = 0.0
# step 253: x = 2.0, gradient = 0.0
# step 254: x = 2.0, gradient = 0.0
# step 255: x = 2.0, gradient = 0.0
# step 256: x = 2.0, gradient = 0.0
# step 257: x = 2.0, gradient = 0.0
# step 258: x = 2.0, gradient = 0.0
# step 259: x = 2.0, gradient = 0.0
# step 260: x = 2.0, gradient = 0.0
# step 261: x = 2.0, gradient = 0.0
# step 262: x = 2.0, gradient = 0.0
# step 263: x = 2.0, gradient = 0.0
# step 264: x = 2.0, gradient = 0.0
# step 265: x = 2.0, gradient = 0.0
# step 266: x = 2.0, gradient = 0.0
# step 267: x = 2.0, gradient = 0.0
# step 268: x = 2.0, gradient = 0.0
# step 269: x = 2.0, gradient = 0.0
# step 270: x = 2.0, gradient = 0.0
# step 271: x = 2.0, gradient = 0.0
# step 272: x = 2.0, gradient = 0.0
# step 273: x = 2.0, gradient = 0.0
# step 274: x = 2.0, gradient = 0.0
# step 275: x = 2.0, gradient = 0.0
# step 276: x = 2.0, gradient = 0.0
# step 277: x = 2.0, gradient = 0.0
# step 278: x = 2.0, gradient = 0.0
# step 279: x = 2.0, gradient = 0.0
# step 280: x = 2.0, gradient = 0.0
# step 281: x = 2.0, gradient = 0.0
# step 282: x = 2.0, gradient = 0.0
# step 283: x = 2.0, gradient = 0.0
# step 284: x = 2.0, gradient = 0.0
# step 285: x = 2.0, gradient = 0.0
# step 286: x = 2.0, gradient = 0.0
# step 287: x = 2.0, gradient = 0.0
# step 288: x = 2.0, gradient = 0.0
# step 289: x = 2.0, gradient = 0.0
# step 290: x = 2.0, gradient = 0.0
# step 291: x = 2.0, gradient = 0.0
# step 292: x = 2.0, gradient = 0.0
# step 293: x = 2.0, gradient = 0.0
# step 294: x = 2.0, gradient = 0.0
# step 295: x = 2.0, gradient = 0.0
# step 296: x = 2.0, gradient = 0.0
# step 297: x = 2.0, gradient = 0.0
# step 298: x = 2.0, gradient = 0.0
# step 299: x = 2.0, gradient = 0.0
# step 300: x = 2.0, gradient = 0.0
# step 301: x = 2.0, gradient = 0.0
# step 302: x = 2.0, gradient = 0.0
# step 303: x = 2.0, gradient = 0.0
# step 304: x = 2.0, gradient = 0.0
# step 305: x = 2.0, gradient = 0.0
# step 306: x = 2.0, gradient = 0.0
# step 307: x = 2.0, gradient = 0.0
# step 308: x = 2.0, gradient = 0.0
# step 309: x = 2.0, gradient = 0.0
# step 310: x = 2.0, gradient = 0.0
# step 311: x = 2.0, gradient = 0.0
# step 312: x = 2.0, gradient = 0.0
# step 313: x = 2.0, gradient = 0.0
# step 314: x = 2.0, gradient = 0.0
# step 315: x = 2.0, gradient = 0.0
# step 316: x = 2.0, gradient = 0.0
# step 317: x = 2.0, gradient = 0.0
# step 318: x = 2.0, gradient = 0.0
# step 319: x = 2.0, gradient = 0.0
# step 320: x = 2.0, gradient = 0.0
# step 321: x = 2.0, gradient = 0.0
# step 322: x = 2.0, gradient = 0.0
# step 323: x = 2.0, gradient = 0.0
# step 324: x = 2.0, gradient = 0.0
# step 325: x = 2.0, gradient = 0.0
# step 326: x = 2.0, gradient = 0.0
# step 327: x = 2.0, gradient = 0.0
# step 328: x = 2.0, gradient = 0.0
# step 329: x = 2.0, gradient = 0.0
# step 330: x = 2.0, gradient = 0.0
# step 331: x = 2.0, gradient = 0.0
# step 332: x = 2.0, gradient = 0.0
# step 333: x = 2.0, gradient = 0.0
# step 334: x = 2.0, gradient = 0.0
# step 335: x = 2.0, gradient = 0.0
# step 336: x = 2.0, gradient = 0.0
# step 337: x = 2.0, gradient = 0.0
# step 338: x = 2.0, gradient = 0.0
# step 339: x = 2.0, gradient = 0.0
# step 340: x = 2.0, gradient = 0.0
# step 341: x = 2.0, gradient = 0.0
# step 342: x = 2.0, gradient = 0.0
# step 343: x = 2.0, gradient = 0.0
# step 344: x = 2.0, gradient = 0.0
# step 345: x = 2.0, gradient = 0.0
# step 346: x = 2.0, gradient = 0.0
# step 347: x = 2.0, gradient = 0.0
# step 348: x = 2.0, gradient = 0.0
# step 349: x = 2.0, gradient = 0.0
# step 350: x = 2.0, gradient = 0.0
# step 351: x = 2.0, gradient = 0.0
# step 352: x = 2.0, gradient = 0.0
# step 353: x = 2.0, gradient = 0.0
# step 354: x = 2.0, gradient = 0.0
# step 355: x = 2.0, gradient = 0.0
# step 356: x = 2.0, gradient = 0.0
# step 357: x = 2.0, gradient = 0.0
# step 358: x = 2.0, gradient = 0.0
# step 359: x = 2.0, gradient = 0.0
# step 360: x = 2.0, gradient = 0.0
# step 361: x = 2.0, gradient = 0.0
# step 362: x = 2.0, gradient = 0.0
# step 363: x = 2.0, gradient = 0.0
# step 364: x = 2.0, gradient = 0.0
# step 365: x = 2.0, gradient = 0.0
# step 366: x = 2.0, gradient = 0.0
# step 367: x = 2.0, gradient = 0.0
# step 368: x = 2.0, gradient = 0.0
# step 369: x = 2.0, gradient = 0.0
# step 370: x = 2.0, gradient = 0.0
# step 371: x = 2.0, gradient = 0.0
# step 372: x = 2.0, gradient = 0.0
# step 373: x = 2.0, gradient = 0.0
# step 374: x = 2.0, gradient = 0.0
# step 375: x = 2.0, gradient = 0.0
# step 376: x = 2.0, gradient = 0.0
# step 377: x = 2.0, gradient = 0.0
# step 378: x = 2.0, gradient = 0.0
# step 379: x = 2.0, gradient = 0.0
# step 380: x = 2.0, gradient = 0.0
# step 381: x = 2.0, gradient = 0.0
# step 382: x = 2.0, gradient = 0.0
# step 383: x = 2.0, gradient = 0.0
# step 384: x = 2.0, gradient = 0.0
# step 385: x = 2.0, gradient = 0.0
# step 386: x = 2.0, gradient = 0.0
# step 387: x = 2.0, gradient = 0.0
# step 388: x = 2.0, gradient = 0.0
# step 389: x = 2.0, gradient = 0.0
# step 390: x = 2.0, gradient = 0.0
# step 391: x = 2.0, gradient = 0.0
# step 392: x = 2.0, gradient = 0.0
# step 393: x = 2.0, gradient = 0.0
# step 394: x = 2.0, gradient = 0.0
# step 395: x = 2.0, gradient = 0.0
# step 396: x = 2.0, gradient = 0.0
# step 397: x = 2.0, gradient = 0.0
# step 398: x = 2.0, gradient = 0.0
# step 399: x = 2.0, gradient = 0.0
# step 400: x = 2.0, gradient = 0.0
# step 401: x = 2.0, gradient = 0.0
# step 402: x = 2.0, gradient = 0.0
# step 403: x = 2.0, gradient = 0.0
# step 404: x = 2.0, gradient = 0.0
# step 405: x = 2.0, gradient = 0.0
# step 406: x = 2.0, gradient = 0.0
# step 407: x = 2.0, gradient = 0.0
# step 408: x = 2.0, gradient = 0.0
# step 409: x = 2.0, gradient = 0.0
# step 410: x = 2.0, gradient = 0.0
# step 411: x = 2.0, gradient = 0.0
# step 412: x = 2.0, gradient = 0.0
# step 413: x = 2.0, gradient = 0.0
# step 414: x = 2.0, gradient = 0.0
# step 415: x = 2.0, gradient = 0.0
# step 416: x = 2.0, gradient = 0.0
# step 417: x = 2.0, gradient = 0.0
# step 418: x = 2.0, gradient = 0.0
# step 419: x = 2.0, gradient = 0.0
# step 420: x = 2.0, gradient = 0.0
# step 421: x = 2.0, gradient = 0.0
# step 422: x = 2.0, gradient = 0.0
# step 423: x = 2.0, gradient = 0.0
# step 424: x = 2.0, gradient = 0.0
# step 425: x = 2.0, gradient = 0.0
# step 426: x = 2.0, gradient = 0.0
# step 427: x = 2.0, gradient = 0.0
# step 428: x = 2.0, gradient = 0.0
# step 429: x = 2.0, gradient = 0.0
# step 430: x = 2.0, gradient = 0.0
# step 431: x = 2.0, gradient = 0.0
# step 432: x = 2.0, gradient = 0.0
# step 433: x = 2.0, gradient = 0.0
# step 434: x = 2.0, gradient = 0.0
# step 435: x = 2.0, gradient = 0.0
# step 436: x = 2.0, gradient = 0.0
# step 437: x = 2.0, gradient = 0.0
# step 438: x = 2.0, gradient = 0.0
# step 439: x = 2.0, gradient = 0.0
# step 440: x = 2.0, gradient = 0.0
# step 441: x = 2.0, gradient = 0.0
# step 442: x = 2.0, gradient = 0.0
# step 443: x = 2.0, gradient = 0.0
# step 444: x = 2.0, gradient = 0.0
# step 445: x = 2.0, gradient = 0.0
# step 446: x = 2.0, gradient = 0.0
# step 447: x = 2.0, gradient = 0.0
# step 448: x = 2.0, gradient = 0.0
# step 449: x = 2.0, gradient = 0.0
# step 450: x = 2.0, gradient = 0.0
# step 451: x = 2.0, gradient = 0.0
# step 452: x = 2.0, gradient = 0.0
# step 453: x = 2.0, gradient = 0.0
# step 454: x = 2.0, gradient = 0.0
# step 455: x = 2.0, gradient = 0.0
# step 456: x = 2.0, gradient = 0.0
# step 457: x = 2.0, gradient = 0.0
# step 458: x = 2.0, gradient = 0.0
# step 459: x = 2.0, gradient = 0.0
# step 460: x = 2.0, gradient = 0.0
# step 461: x = 2.0, gradient = 0.0
# step 462: x = 2.0, gradient = 0.0
# step 463: x = 2.0, gradient = 0.0
# step 464: x = 2.0, gradient = 0.0
# step 465: x = 2.0, gradient = 0.0
# step 466: x = 2.0, gradient = 0.0
# step 467: x = 2.0, gradient = 0.0
# step 468: x = 2.0, gradient = 0.0
# step 469: x = 2.0, gradient = 0.0
# step 470: x = 2.0, gradient = 0.0
# step 471: x = 2.0, gradient = 0.0
# step 472: x = 2.0, gradient = 0.0
# step 473: x = 2.0, gradient = 0.0
# step 474: x = 2.0, gradient = 0.0
# step 475: x = 2.0, gradient = 0.0
# step 476: x = 2.0, gradient = 0.0
# step 477: x = 2.0, gradient = 0.0
# step 478: x = 2.0, gradient = 0.0
# step 479: x = 2.0, gradient = 0.0
# step 480: x = 2.0, gradient = 0.0
# step 481: x = 2.0, gradient = 0.0
# step 482: x = 2.0, gradient = 0.0
# step 483: x = 2.0, gradient = 0.0
# step 484: x = 2.0, gradient = 0.0
# step 485: x = 2.0, gradient = 0.0
# step 486: x = 2.0, gradient = 0.0
# step 487: x = 2.0, gradient = 0.0
# step 488: x = 2.0, gradient = 0.0
# step 489: x = 2.0, gradient = 0.0
# step 490: x = 2.0, gradient = 0.0
# step 491: x = 2.0, gradient = 0.0
# step 492: x = 2.0, gradient = 0.0
# step 493: x = 2.0, gradient = 0.0
# step 494: x = 2.0, gradient = 0.0
# step 495: x = 2.0, gradient = 0.0
# step 496: x = 2.0, gradient = 0.0
# step 497: x = 2.0, gradient = 0.0
# step 498: x = 2.0, gradient = 0.0
# step 499: x = 2.0, gradient = 0.0
# step 500: x = 2.0, gradient = 0.0
# step 501: x = 2.0, gradient = 0.0
# step 502: x = 2.0, gradient = 0.0
# step 503: x = 2.0, gradient = 0.0
# step 504: x = 2.0, gradient = 0.0
# step 505: x = 2.0, gradient = 0.0
# step 506: x = 2.0, gradient = 0.0
# step 507: x = 2.0, gradient = 0.0
# step 508: x = 2.0, gradient = 0.0
# step 509: x = 2.0, gradient = 0.0
# step 510: x = 2.0, gradient = 0.0
# step 511: x = 2.0, gradient = 0.0
# step 512: x = 2.0, gradient = 0.0
# step 513: x = 2.0, gradient = 0.0
# step 514: x = 2.0, gradient = 0.0
# step 515: x = 2.0, gradient = 0.0
# step 516: x = 2.0, gradient = 0.0
# step 517: x = 2.0, gradient = 0.0
# step 518: x = 2.0, gradient = 0.0
# step 519: x = 2.0, gradient = 0.0
# step 520: x = 2.0, gradient = 0.0
# step 521: x = 2.0, gradient = 0.0
# step 522: x = 2.0, gradient = 0.0
# step 523: x = 2.0, gradient = 0.0
# step 524: x = 2.0, gradient = 0.0
# step 525: x = 2.0, gradient = 0.0
# step 526: x = 2.0, gradient = 0.0
# step 527: x = 2.0, gradient = 0.0
# step 528: x = 2.0, gradient = 0.0
# step 529: x = 2.0, gradient = 0.0
# step 530: x = 2.0, gradient = 0.0
# step 531: x = 2.0, gradient = 0.0
# step 532: x = 2.0, gradient = 0.0
# step 533: x = 2.0, gradient = 0.0
# step 534: x = 2.0, gradient = 0.0
# step 535: x = 2.0, gradient = 0.0
# step 536: x = 2.0, gradient = 0.0
# step 537: x = 2.0, gradient = 0.0
# step 538: x = 2.0, gradient = 0.0
# step 539: x = 2.0, gradient = 0.0
# step 540: x = 2.0, gradient = 0.0
# step 541: x = 2.0, gradient = 0.0
# step 542: x = 2.0, gradient = 0.0
# step 543: x = 2.0, gradient = 0.0
# step 544: x = 2.0, gradient = 0.0
# step 545: x = 2.0, gradient = 0.0
# step 546: x = 2.0, gradient = 0.0
# step 547: x = 2.0, gradient = 0.0
# step 548: x = 2.0, gradient = 0.0
# step 549: x = 2.0, gradient = 0.0
# step 550: x = 2.0, gradient = 0.0
# step 551: x = 2.0, gradient = 0.0
# step 552: x = 2.0, gradient = 0.0
# step 553: x = 2.0, gradient = 0.0
# step 554: x = 2.0, gradient = 0.0
# step 555: x = 2.0, gradient = 0.0
# step 556: x = 2.0, gradient = 0.0
# step 557: x = 2.0, gradient = 0.0
# step 558: x = 2.0, gradient = 0.0
# step 559: x = 2.0, gradient = 0.0
# step 560: x = 2.0, gradient = 0.0
# step 561: x = 2.0, gradient = 0.0
# step 562: x = 2.0, gradient = 0.0
# step 563: x = 2.0, gradient = 0.0
# step 564: x = 2.0, gradient = 0.0
# step 565: x = 2.0, gradient = 0.0
# step 566: x = 2.0, gradient = 0.0
# step 567: x = 2.0, gradient = 0.0
# step 568: x = 2.0, gradient = 0.0
# step 569: x = 2.0, gradient = 0.0
# step 570: x = 2.0, gradient = 0.0
# step 571: x = 2.0, gradient = 0.0
# step 572: x = 2.0, gradient = 0.0
# step 573: x = 2.0, gradient = 0.0
# step 574: x = 2.0, gradient = 0.0
# step 575: x = 2.0, gradient = 0.0
# step 576: x = 2.0, gradient = 0.0
# step 577: x = 2.0, gradient = 0.0
# step 578: x = 2.0, gradient = 0.0
# step 579: x = 2.0, gradient = 0.0
# step 580: x = 2.0, gradient = 0.0
# step 581: x = 2.0, gradient = 0.0
# step 582: x = 2.0, gradient = 0.0
# step 583: x = 2.0, gradient = 0.0
# step 584: x = 2.0, gradient = 0.0
# step 585: x = 2.0, gradient = 0.0
# step 586: x = 2.0, gradient = 0.0
# step 587: x = 2.0, gradient = 0.0
# step 588: x = 2.0, gradient = 0.0
# step 589: x = 2.0, gradient = 0.0
# step 590: x = 2.0, gradient = 0.0
# step 591: x = 2.0, gradient = 0.0
# step 592: x = 2.0, gradient = 0.0
# step 593: x = 2.0, gradient = 0.0
# step 594: x = 2.0, gradient = 0.0
# step 595: x = 2.0, gradient = 0.0
# step 596: x = 2.0, gradient = 0.0
# step 597: x = 2.0, gradient = 0.0
# step 598: x = 2.0, gradient = 0.0
# step 599: x = 2.0, gradient = 0.0
# step 600: x = 2.0, gradient = 0.0
# step 601: x = 2.0, gradient = 0.0
# step 602: x = 2.0, gradient = 0.0
# step 603: x = 2.0, gradient = 0.0
# step 604: x = 2.0, gradient = 0.0
# step 605: x = 2.0, gradient = 0.0
# step 606: x = 2.0, gradient = 0.0
# step 607: x = 2.0, gradient = 0.0
# step 608: x = 2.0, gradient = 0.0
# step 609: x = 2.0, gradient = 0.0
# step 610: x = 2.0, gradient = 0.0
# step 611: x = 2.0, gradient = 0.0
# step 612: x = 2.0, gradient = 0.0
# step 613: x = 2.0, gradient = 0.0
# step 614: x = 2.0, gradient = 0.0
# step 615: x = 2.0, gradient = 0.0
# step 616: x = 2.0, gradient = 0.0
# step 617: x = 2.0, gradient = 0.0
# step 618: x = 2.0, gradient = 0.0
# step 619: x = 2.0, gradient = 0.0
# step 620: x = 2.0, gradient = 0.0
# step 621: x = 2.0, gradient = 0.0
# step 622: x = 2.0, gradient = 0.0
# step 623: x = 2.0, gradient = 0.0
# step 624: x = 2.0, gradient = 0.0
# step 625: x = 2.0, gradient = 0.0
# step 626: x = 2.0, gradient = 0.0
# step 627: x = 2.0, gradient = 0.0
# step 628: x = 2.0, gradient = 0.0
# step 629: x = 2.0, gradient = 0.0
# step 630: x = 2.0, gradient = 0.0
# step 631: x = 2.0, gradient = 0.0
# step 632: x = 2.0, gradient = 0.0
# step 633: x = 2.0, gradient = 0.0
# step 634: x = 2.0, gradient = 0.0
# step 635: x = 2.0, gradient = 0.0
# step 636: x = 2.0, gradient = 0.0
# step 637: x = 2.0, gradient = 0.0
# step 638: x = 2.0, gradient = 0.0
# step 639: x = 2.0, gradient = 0.0
# step 640: x = 2.0, gradient = 0.0
# step 641: x = 2.0, gradient = 0.0
# step 642: x = 2.0, gradient = 0.0
# step 643: x = 2.0, gradient = 0.0
# step 644: x = 2.0, gradient = 0.0
# step 645: x = 2.0, gradient = 0.0
# step 646: x = 2.0, gradient = 0.0
# step 647: x = 2.0, gradient = 0.0
# step 648: x = 2.0, gradient = 0.0
# step 649: x = 2.0, gradient = 0.0
# step 650: x = 2.0, gradient = 0.0
# step 651: x = 2.0, gradient = 0.0
# step 652: x = 2.0, gradient = 0.0
# step 653: x = 2.0, gradient = 0.0
# step 654: x = 2.0, gradient = 0.0
# step 655: x = 2.0, gradient = 0.0
# step 656: x = 2.0, gradient = 0.0
# step 657: x = 2.0, gradient = 0.0
# step 658: x = 2.0, gradient = 0.0
# step 659: x = 2.0, gradient = 0.0
# step 660: x = 2.0, gradient = 0.0
# step 661: x = 2.0, gradient = 0.0
# step 662: x = 2.0, gradient = 0.0
# step 663: x = 2.0, gradient = 0.0
# step 664: x = 2.0, gradient = 0.0
# step 665: x = 2.0, gradient = 0.0
# step 666: x = 2.0, gradient = 0.0
# step 667: x = 2.0, gradient = 0.0
# step 668: x = 2.0, gradient = 0.0
# step 669: x = 2.0, gradient = 0.0
# step 670: x = 2.0, gradient = 0.0
# step 671: x = 2.0, gradient = 0.0
# step 672: x = 2.0, gradient = 0.0
# step 673: x = 2.0, gradient = 0.0
# step 674: x = 2.0, gradient = 0.0
# step 675: x = 2.0, gradient = 0.0
# step 676: x = 2.0, gradient = 0.0
# step 677: x = 2.0, gradient = 0.0
# step 678: x = 2.0, gradient = 0.0
# step 679: x = 2.0, gradient = 0.0
# step 680: x = 2.0, gradient = 0.0
# step 681: x = 2.0, gradient = 0.0
# step 682: x = 2.0, gradient = 0.0
# step 683: x = 2.0, gradient = 0.0
# step 684: x = 2.0, gradient = 0.0
# step 685: x = 2.0, gradient = 0.0
# step 686: x = 2.0, gradient = 0.0
# step 687: x = 2.0, gradient = 0.0
# step 688: x = 2.0, gradient = 0.0
# step 689: x = 2.0, gradient = 0.0
# step 690: x = 2.0, gradient = 0.0
# step 691: x = 2.0, gradient = 0.0
# step 692: x = 2.0, gradient = 0.0
# step 693: x = 2.0, gradient = 0.0
# step 694: x = 2.0, gradient = 0.0
# step 695: x = 2.0, gradient = 0.0
# step 696: x = 2.0, gradient = 0.0
# step 697: x = 2.0, gradient = 0.0
# step 698: x = 2.0, gradient = 0.0
# step 699: x = 2.0, gradient = 0.0
# step 700: x = 2.0, gradient = 0.0
# step 701: x = 2.0, gradient = 0.0
# step 702: x = 2.0, gradient = 0.0
# step 703: x = 2.0, gradient = 0.0
# step 704: x = 2.0, gradient = 0.0
# step 705: x = 2.0, gradient = 0.0
# step 706: x = 2.0, gradient = 0.0
# step 707: x = 2.0, gradient = 0.0
# step 708: x = 2.0, gradient = 0.0
# step 709: x = 2.0, gradient = 0.0
# step 710: x = 2.0, gradient = 0.0
# step 711: x = 2.0, gradient = 0.0
# step 712: x = 2.0, gradient = 0.0
# step 713: x = 2.0, gradient = 0.0
# step 714: x = 2.0, gradient = 0.0
# step 715: x = 2.0, gradient = 0.0
# step 716: x = 2.0, gradient = 0.0
# step 717: x = 2.0, gradient = 0.0
# step 718: x = 2.0, gradient = 0.0
# step 719: x = 2.0, gradient = 0.0
# step 720: x = 2.0, gradient = 0.0
# step 721: x = 2.0, gradient = 0.0
# step 722: x = 2.0, gradient = 0.0
# step 723: x = 2.0, gradient = 0.0
# step 724: x = 2.0, gradient = 0.0
# step 725: x = 2.0, gradient = 0.0
# step 726: x = 2.0, gradient = 0.0
# step 727: x = 2.0, gradient = 0.0
# step 728: x = 2.0, gradient = 0.0
# step 729: x = 2.0, gradient = 0.0
# step 730: x = 2.0, gradient = 0.0
# step 731: x = 2.0, gradient = 0.0
# step 732: x = 2.0, gradient = 0.0
# step 733: x = 2.0, gradient = 0.0
# step 734: x = 2.0, gradient = 0.0
# step 735: x = 2.0, gradient = 0.0
# step 736: x = 2.0, gradient = 0.0
# step 737: x = 2.0, gradient = 0.0
# step 738: x = 2.0, gradient = 0.0
# step 739: x = 2.0, gradient = 0.0
# step 740: x = 2.0, gradient = 0.0
# step 741: x = 2.0, gradient = 0.0
# step 742: x = 2.0, gradient = 0.0
# step 743: x = 2.0, gradient = 0.0
# step 744: x = 2.0, gradient = 0.0
# step 745: x = 2.0, gradient = 0.0
# step 746: x = 2.0, gradient = 0.0
# step 747: x = 2.0, gradient = 0.0
# step 748: x = 2.0, gradient = 0.0
# step 749: x = 2.0, gradient = 0.0
# step 750: x = 2.0, gradient = 0.0
# step 751: x = 2.0, gradient = 0.0
# step 752: x = 2.0, gradient = 0.0
# step 753: x = 2.0, gradient = 0.0
# step 754: x = 2.0, gradient = 0.0
# step 755: x = 2.0, gradient = 0.0
# step 756: x = 2.0, gradient = 0.0
# step 757: x = 2.0, gradient = 0.0
# step 758: x = 2.0, gradient = 0.0
# step 759: x = 2.0, gradient = 0.0
# step 760: x = 2.0, gradient = 0.0
# step 761: x = 2.0, gradient = 0.0
# step 762: x = 2.0, gradient = 0.0
# step 763: x = 2.0, gradient = 0.0
# step 764: x = 2.0, gradient = 0.0
# step 765: x = 2.0, gradient = 0.0
# step 766: x = 2.0, gradient = 0.0
# step 767: x = 2.0, gradient = 0.0
# step 768: x = 2.0, gradient = 0.0
# step 769: x = 2.0, gradient = 0.0
# step 770: x = 2.0, gradient = 0.0
# step 771: x = 2.0, gradient = 0.0
# step 772: x = 2.0, gradient = 0.0
# step 773: x = 2.0, gradient = 0.0
# step 774: x = 2.0, gradient = 0.0
# step 775: x = 2.0, gradient = 0.0
# step 776: x = 2.0, gradient = 0.0
# step 777: x = 2.0, gradient = 0.0
# step 778: x = 2.0, gradient = 0.0
# step 779: x = 2.0, gradient = 0.0
# step 780: x = 2.0, gradient = 0.0
# step 781: x = 2.0, gradient = 0.0
# step 782: x = 2.0, gradient = 0.0
# step 783: x = 2.0, gradient = 0.0
# step 784: x = 2.0, gradient = 0.0
# step 785: x = 2.0, gradient = 0.0
# step 786: x = 2.0, gradient = 0.0
# step 787: x = 2.0, gradient = 0.0
# step 788: x = 2.0, gradient = 0.0
# step 789: x = 2.0, gradient = 0.0
# step 790: x = 2.0, gradient = 0.0
# step 791: x = 2.0, gradient = 0.0
# step 792: x = 2.0, gradient = 0.0
# step 793: x = 2.0, gradient = 0.0
# step 794: x = 2.0, gradient = 0.0
# step 795: x = 2.0, gradient = 0.0
# step 796: x = 2.0, gradient = 0.0
# step 797: x = 2.0, gradient = 0.0
# step 798: x = 2.0, gradient = 0.0
# step 799: x = 2.0, gradient = 0.0
# step 800: x = 2.0, gradient = 0.0
# step 801: x = 2.0, gradient = 0.0
# step 802: x = 2.0, gradient = 0.0
# step 803: x = 2.0, gradient = 0.0
# step 804: x = 2.0, gradient = 0.0
# step 805: x = 2.0, gradient = 0.0
# step 806: x = 2.0, gradient = 0.0
# step 807: x = 2.0, gradient = 0.0
# step 808: x = 2.0, gradient = 0.0
# step 809: x = 2.0, gradient = 0.0
# step 810: x = 2.0, gradient = 0.0
# step 811: x = 2.0, gradient = 0.0
# step 812: x = 2.0, gradient = 0.0
# step 813: x = 2.0, gradient = 0.0
# step 814: x = 2.0, gradient = 0.0
# step 815: x = 2.0, gradient = 0.0
# step 816: x = 2.0, gradient = 0.0
# step 817: x = 2.0, gradient = 0.0
# step 818: x = 2.0, gradient = 0.0
# step 819: x = 2.0, gradient = 0.0
# step 820: x = 2.0, gradient = 0.0
# step 821: x = 2.0, gradient = 0.0
# step 822: x = 2.0, gradient = 0.0
# step 823: x = 2.0, gradient = 0.0
# step 824: x = 2.0, gradient = 0.0
# step 825: x = 2.0, gradient = 0.0
# step 826: x = 2.0, gradient = 0.0
# step 827: x = 2.0, gradient = 0.0
# step 828: x = 2.0, gradient = 0.0
# step 829: x = 2.0, gradient = 0.0
# step 830: x = 2.0, gradient = 0.0
# step 831: x = 2.0, gradient = 0.0
# step 832: x = 2.0, gradient = 0.0
# step 833: x = 2.0, gradient = 0.0
# step 834: x = 2.0, gradient = 0.0
# step 835: x = 2.0, gradient = 0.0
# step 836: x = 2.0, gradient = 0.0
# step 837: x = 2.0, gradient = 0.0
# step 838: x = 2.0, gradient = 0.0
# step 839: x = 2.0, gradient = 0.0
# step 840: x = 2.0, gradient = 0.0
# step 841: x = 2.0, gradient = 0.0
# step 842: x = 2.0, gradient = 0.0
# step 843: x = 2.0, gradient = 0.0
# step 844: x = 2.0, gradient = 0.0
# step 845: x = 2.0, gradient = 0.0
# step 846: x = 2.0, gradient = 0.0
# step 847: x = 2.0, gradient = 0.0
# step 848: x = 2.0, gradient = 0.0
# step 849: x = 2.0, gradient = 0.0
# step 850: x = 2.0, gradient = 0.0
# step 851: x = 2.0, gradient = 0.0
# step 852: x = 2.0, gradient = 0.0
# step 853: x = 2.0, gradient = 0.0
# step 854: x = 2.0, gradient = 0.0
# step 855: x = 2.0, gradient = 0.0
# step 856: x = 2.0, gradient = 0.0
# step 857: x = 2.0, gradient = 0.0
# step 858: x = 2.0, gradient = 0.0
# step 859: x = 2.0, gradient = 0.0
# step 860: x = 2.0, gradient = 0.0
# step 861: x = 2.0, gradient = 0.0
# step 862: x = 2.0, gradient = 0.0
# step 863: x = 2.0, gradient = 0.0
# step 864: x = 2.0, gradient = 0.0
# step 865: x = 2.0, gradient = 0.0
# step 866: x = 2.0, gradient = 0.0
# step 867: x = 2.0, gradient = 0.0
# step 868: x = 2.0, gradient = 0.0
# step 869: x = 2.0, gradient = 0.0
# step 870: x = 2.0, gradient = 0.0
# step 871: x = 2.0, gradient = 0.0
# step 872: x = 2.0, gradient = 0.0
# step 873: x = 2.0, gradient = 0.0
# step 874: x = 2.0, gradient = 0.0
# step 875: x = 2.0, gradient = 0.0
# step 876: x = 2.0, gradient = 0.0
# step 877: x = 2.0, gradient = 0.0
# step 878: x = 2.0, gradient = 0.0
# step 879: x = 2.0, gradient = 0.0
# step 880: x = 2.0, gradient = 0.0
# step 881: x = 2.0, gradient = 0.0
# step 882: x = 2.0, gradient = 0.0
# step 883: x = 2.0, gradient = 0.0
# step 884: x = 2.0, gradient = 0.0
# step 885: x = 2.0, gradient = 0.0
# step 886: x = 2.0, gradient = 0.0
# step 887: x = 2.0, gradient = 0.0
# step 888: x = 2.0, gradient = 0.0
# step 889: x = 2.0, gradient = 0.0
# step 890: x = 2.0, gradient = 0.0
# step 891: x = 2.0, gradient = 0.0
# step 892: x = 2.0, gradient = 0.0
# step 893: x = 2.0, gradient = 0.0
# step 894: x = 2.0, gradient = 0.0
# step 895: x = 2.0, gradient = 0.0
# step 896: x = 2.0, gradient = 0.0
# step 897: x = 2.0, gradient = 0.0
# step 898: x = 2.0, gradient = 0.0
# step 899: x = 2.0, gradient = 0.0
# step 900: x = 2.0, gradient = 0.0
# step 901: x = 2.0, gradient = 0.0
# step 902: x = 2.0, gradient = 0.0
# step 903: x = 2.0, gradient = 0.0
# step 904: x = 2.0, gradient = 0.0
# step 905: x = 2.0, gradient = 0.0
# step 906: x = 2.0, gradient = 0.0
# step 907: x = 2.0, gradient = 0.0
# step 908: x = 2.0, gradient = 0.0
# step 909: x = 2.0, gradient = 0.0
# step 910: x = 2.0, gradient = 0.0
# step 911: x = 2.0, gradient = 0.0
# step 912: x = 2.0, gradient = 0.0
# step 913: x = 2.0, gradient = 0.0
# step 914: x = 2.0, gradient = 0.0
# step 915: x = 2.0, gradient = 0.0
# step 916: x = 2.0, gradient = 0.0
# step 917: x = 2.0, gradient = 0.0
# step 918: x = 2.0, gradient = 0.0
# step 919: x = 2.0, gradient = 0.0
# step 920: x = 2.0, gradient = 0.0
# step 921: x = 2.0, gradient = 0.0
# step 922: x = 2.0, gradient = 0.0
# step 923: x = 2.0, gradient = 0.0
# step 924: x = 2.0, gradient = 0.0
# step 925: x = 2.0, gradient = 0.0
# step 926: x = 2.0, gradient = 0.0
# step 927: x = 2.0, gradient = 0.0
# step 928: x = 2.0, gradient = 0.0
# step 929: x = 2.0, gradient = 0.0
# step 930: x = 2.0, gradient = 0.0
# step 931: x = 2.0, gradient = 0.0
# step 932: x = 2.0, gradient = 0.0
# step 933: x = 2.0, gradient = 0.0
# step 934: x = 2.0, gradient = 0.0
# step 935: x = 2.0, gradient = 0.0
# step 936: x = 2.0, gradient = 0.0
# step 937: x = 2.0, gradient = 0.0
# step 938: x = 2.0, gradient = 0.0
# step 939: x = 2.0, gradient = 0.0
# step 940: x = 2.0, gradient = 0.0
# step 941: x = 2.0, gradient = 0.0
# step 942: x = 2.0, gradient = 0.0
# step 943: x = 2.0, gradient = 0.0
# step 944: x = 2.0, gradient = 0.0
# step 945: x = 2.0, gradient = 0.0
# step 946: x = 2.0, gradient = 0.0
# step 947: x = 2.0, gradient = 0.0
# step 948: x = 2.0, gradient = 0.0
# step 949: x = 2.0, gradient = 0.0
# step 950: x = 2.0, gradient = 0.0
# step 951: x = 2.0, gradient = 0.0
# step 952: x = 2.0, gradient = 0.0
# step 953: x = 2.0, gradient = 0.0
# step 954: x = 2.0, gradient = 0.0
# step 955: x = 2.0, gradient = 0.0
# step 956: x = 2.0, gradient = 0.0
# step 957: x = 2.0, gradient = 0.0
# step 958: x = 2.0, gradient = 0.0
# step 959: x = 2.0, gradient = 0.0
# step 960: x = 2.0, gradient = 0.0
# step 961: x = 2.0, gradient = 0.0
# step 962: x = 2.0, gradient = 0.0
# step 963: x = 2.0, gradient = 0.0
# step 964: x = 2.0, gradient = 0.0
# step 965: x = 2.0, gradient = 0.0
# step 966: x = 2.0, gradient = 0.0
# step 967: x = 2.0, gradient = 0.0
# step 968: x = 2.0, gradient = 0.0
# step 969: x = 2.0, gradient = 0.0
# step 970: x = 2.0, gradient = 0.0
# step 971: x = 2.0, gradient = 0.0
# step 972: x = 2.0, gradient = 0.0
# step 973: x = 2.0, gradient = 0.0
# step 974: x = 2.0, gradient = 0.0
# step 975: x = 2.0, gradient = 0.0
# step 976: x = 2.0, gradient = 0.0
# step 977: x = 2.0, gradient = 0.0
# step 978: x = 2.0, gradient = 0.0
# step 979: x = 2.0, gradient = 0.0
# step 980: x = 2.0, gradient = 0.0
# step 981: x = 2.0, gradient = 0.0
# step 982: x = 2.0, gradient = 0.0
# step 983: x = 2.0, gradient = 0.0
# step 984: x = 2.0, gradient = 0.0
# step 985: x = 2.0, gradient = 0.0
# step 986: x = 2.0, gradient = 0.0
# step 987: x = 2.0, gradient = 0.0
# step 988: x = 2.0, gradient = 0.0
# step 989: x = 2.0, gradient = 0.0
# step 990: x = 2.0, gradient = 0.0
# step 991: x = 2.0, gradient = 0.0
# step 992: x = 2.0, gradient = 0.0
# step 993: x = 2.0, gradient = 0.0
# step 994: x = 2.0, gradient = 0.0
# step 995: x = 2.0, gradient = 0.0
# step 996: x = 2.0, gradient = 0.0
# step 997: x = 2.0, gradient = 0.0
# step 998: x = 2.0, gradient = 0.0
# step 999: x = 2.0, gradient = 0.0
# step 1000: x = 2.0, gradient = 0.0
# 2.0
