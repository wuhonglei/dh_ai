# %%
import pandas as pd

data = pd.read_csv('./data/name_len.csv')
# shopee title 单词数量分布
data['name_len'].plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
import pandas as pd

data = pd.read_csv('./data/keyword.csv')
data['title_len'] = data['clean_name'].apply(lambda x: len(x))
data['title_len'].plot(kind='hist', bins=100)
# Out:
# <Axes: ylabel='Frequency'>
