# %%
j = lambda x: x ** 2 + 4 * x + 5 # 损失函数
grad_j = lambda x: 2 * x + 4 # 损失函数的梯度

x = 0 # 初始值
lr = 0.001 # 学习率

for i in range(10000):
    x = x - lr * grad_j(x)
    
print(f'x is :{x}, min value is :{j(x)}')
# Out:
# x is :-1.9999999959594266, min value is :1.0
